# %%
import geopandas as gpd

# %%
branches=gpd.read_file("DATA/Walking_Distance_Quarter_Mile_Buffer_from_Libraries.geojson")

# %%
# this code shows the libraries in Broward County Florida with a quarter mile buffer of the surrounding area
branches.head(10)
# Out:
#    OBJECTID_1  OBJECTID                    ADDRESS             CITY CITY_ID  \
# 0           1         1         50 W Atlantic Blvd    Pompano Beach      PB
# 1           2         2            7300 Pines Blvd   Pembroke Pines      PP
# 2           3         3  3100 Ray Ferrero, Jr Blvd            Davie      DV
# 3           4         4          100 S Andrews Ave  Fort Lauderdale      FL
# 4           5         5         3403 Galt Ocean Dr  Fort Lauderdale      FL
# 5           6         6         5985 N Federal Hwy  Fort Lauderdale      FL
# 6           7         7    1100 Coconut Creek Blvd    Coconut Creek      CK
# 7           8         8          300 S Federal Hwy       Hallandale      HD
# 8           9         9    2050 Civic Center Place          Miramar      MM
# 9          10        10            4735 SW 18th St        West Park      WP
#
#   ZIPCODE     PHONE  SVCAREA                    TYPE TYPE3  ...  \
# 0   33060  357-7595        3  Branch/Cultural Center     B  ...
# ...

# %%
# what is the type of each column
branches.dtypes
# Out:
# OBJECTID_1       int64
# OBJECTID         int64
# ADDRESS         object
# CITY            object
# CITY_ID         object
# ZIPCODE         object
# PHONE           object
# SVCAREA          int64
# TYPE            object
# TYPE3           object
# AGE             object
# SQFT             int64
# FY09OPEXPE       int64
# FUNDTYPE        object
# OWN_LEASE_      object
# FY10WEEKLY     float64
# FY10WEEK_1       int64
# FY10WEEK_2       int64
# CLOSESTBRA      object
# POPSERVED       object
# LAT            float64
# LON            float64
# USNG            object
# LOCCODE         object
# LIBNAME         object
# COMDIST         object
# BUFF_DIST      float64
# ORIG_FID         int64
# ANALYSISAR     float64
# ST_AREA_SH     float64
# ST_LENGTH_     float64
# SHAPEAREA      float64
# SHAPELEN       float64
# geometry      geometry
# dtype: object

# %%
branches.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 34 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID_1  55 non-null     int64
#  1   OBJECTID    55 non-null     int64
#  2   ADDRESS     55 non-null     object
#  3   CITY        55 non-null     object
#  4   CITY_ID     55 non-null     object
#  5   ZIPCODE     55 non-null     object
#  6   PHONE       55 non-null     object
#  7   SVCAREA     55 non-null     int64
#  8   TYPE        55 non-null     object
#  9   TYPE3       55 non-null     object
#  10  AGE         55 non-null     object
#  11  SQFT        55 non-null     int64
#  12  FY09OPEXPE  55 non-null     int64
#  13  FUNDTYPE    55 non-null     object
#  14  OWN_LEASE_  55 non-null     object
#  15  FY10WEEKLY  55 non-null     float64
#  16  FY10WEEK_1  55 non-null     int64
#  17  FY10WEEK_2  55 non-null     int64
#  18  CLOSESTBRA  55 non-null     object
# ...

# %%
branches.shape
# Out:
# (55, 34)

# %%
# what are the column names
branches.columns.to_list()
# Out:
# ['OBJECTID_1',
#  'OBJECTID',
#  'ADDRESS',
#  'CITY',
#  'CITY_ID',
#  'ZIPCODE',
#  'PHONE',
#  'SVCAREA',
#  'TYPE',
#  'TYPE3',
#  'AGE',
#  'SQFT',
#  'FY09OPEXPE',
#  'FUNDTYPE',
#  'OWN_LEASE_',
#  'FY10WEEKLY',
#  'FY10WEEK_1',
#  'FY10WEEK_2',
#  'CLOSESTBRA',
#  'POPSERVED',
#  'LAT',
#  'LON',
#  'USNG',
#  'LOCCODE',
#  'LIBNAME',
#  'COMDIST',
#  'BUFF_DIST',
#  'ORIG_FID',
#  'ANALYSISAR',
#  'ST_AREA_SH',
#  'ST_LENGTH_',
#  'SHAPEAREA',
#  'SHAPELEN',
#  'geometry']

# %%
# show library names
branches['LIBNAME'].sample(10)
# Out:
# 1                            South Regional/Bcc Library
# 12    Pembroke Pines Branch/Walter C. Young Resource...
# 40             Doreen Gauthier Lighthouse Point Library
# 5                                 Imperial Point Branch
# 47                  Helen B. Hoffman Plantation Library
# 17                             Davie/Cooper City Branch
# 31                             Sunrise Dan Pearl Branch
# 25                               Fort Lauderdale Branch
# 7                               Hallandale Beach Branch
# 2     Alvin Sherman, Research And Info. Tech. Ctr At...
# Name: LIBNAME, dtype: object

# %%
# what is the number of libraries in each city
branches['CITY'].value_counts()
# Out:
# Fort Lauderdale     8
# Hollywood           5
# Pompano Beach       4
# Plantation          4
# Davie               3
# Parkland            3
# Oakland Park        3
# Wilton Manors       3
# Pembroke Pines      3
# Deerfield Beach     2
# Lighthouse Point    2
# Lauderhill          2
# Weston              1
# Dania Beach         1
# Lauderdale Lakes    1
# Sunrise             1
# West Park           1
# Tamarac             1
# North Lauderdale    1
# Margate             1
# Coral Springs       1
# Miramar             1
# Hallandale          1
# Coconut Creek       1
# Hallandale Beach    1
# Name: CITY, dtype: int64

# %%
#save it as a new variable
branches_count=branches['CITY'].value_counts()

# %%
# this is the name of the new variable that gives the number of libraries in each city
branches_count
# Out:
# Fort Lauderdale     8
# Hollywood           5
# Pompano Beach       4
# Plantation          4
# Davie               3
# Parkland            3
# Oakland Park        3
# Wilton Manors       3
# Pembroke Pines      3
# Deerfield Beach     2
# Lighthouse Point    2
# Lauderhill          2
# Weston              1
# Dania Beach         1
# Lauderdale Lakes    1
# Sunrise             1
# West Park           1
# Tamarac             1
# North Lauderdale    1
# Margate             1
# Coral Springs       1
# Miramar             1
# Hallandale          1
# Coconut Creek       1
# Hallandale Beach    1
# Name: CITY, dtype: int64

# %%
# convert the series into a dataframe
branches_count=branches_count.reset_index()

# %%
type(branches_count)
# Out:
# pandas.core.frame.DataFrame

# %%
# current columns as a list
branches_count.columns.to_list()
# Out:
# ['index', 'CITY']

# %%
# to rename columns, give it a list column names
branches_count.columns=['city', 'count']

# %%
# a quick bar plot
branches_count.plot()
# Out:
# <AxesSubplot:>

# %%
# give it additonal arguments to make a graph
branches_count.plot.bar(x = 'city', y = 'count', title = 'number of branches within each city')
# Out:
# <AxesSubplot:title={'center':'number of branches within each city'}, xlabel='city'>

# %%
# what was the original data's info
branches.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 34 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID_1  55 non-null     int64
#  1   OBJECTID    55 non-null     int64
#  2   ADDRESS     55 non-null     object
#  3   CITY        55 non-null     object
#  4   CITY_ID     55 non-null     object
#  5   ZIPCODE     55 non-null     object
#  6   PHONE       55 non-null     object
#  7   SVCAREA     55 non-null     int64
#  8   TYPE        55 non-null     object
#  9   TYPE3       55 non-null     object
#  10  AGE         55 non-null     object
#  11  SQFT        55 non-null     int64
#  12  FY09OPEXPE  55 non-null     int64
#  13  FUNDTYPE    55 non-null     object
#  14  OWN_LEASE_  55 non-null     object
#  15  FY10WEEKLY  55 non-null     float64
#  16  FY10WEEK_1  55 non-null     int64
#  17  FY10WEEK_2  55 non-null     int64
#  18  CLOSESTBRA  55 non-null     object
# ...

# %%
# show a dataset with a subset of columns
branches[['ADDRESS', 'CITY', 'ZIPCODE', 'AGE', 'LAT', 'LON', 'LIBNAME', 'BUFF_DIST', 'geometry']]
# Out:
#                       ADDRESS              CITY ZIPCODE   AGE        LAT  \
# 0          50 W Atlantic Blvd     Pompano Beach   33060  1952  26.232160
# 1             7300 Pines Blvd    Pembroke Pines   33023  2007  26.007629
# 2   3100 Ray Ferrero, Jr Blvd             Davie   33314  2001  26.079382
# 3           100 S Andrews Ave   Fort Lauderdale   33301  1984  26.120944
# 4          3403 Galt Ocean Dr   Fort Lauderdale   33308  1992  26.170162
# 5          5985 N Federal Hwy   Fort Lauderdale   33308  1988  26.202059
# 6     1100 Coconut Creek Blvd     Coconut Creek   33066  1994  26.242025
# 7           300 S Federal Hwy        Hallandale   33009  1981  25.981205
# 8     2050 Civic Center Place           Miramar   33025  2008  25.988215
# 9             4735 SW 18th St         West Park   33023  1982  25.994785
# 10            1301 S Ocean Dr         Hollywood   33019  1994  26.004002
# 11        2600 Hollywood Blvd         Hollywood   33020  2006  26.010716
# ...

# %%
branches_trimmed=branches.copy()

# %%
branches_trimmed
# Out:
#     OBJECTID_1  OBJECTID                    ADDRESS              CITY CITY_ID  \
# 0            1         1         50 W Atlantic Blvd     Pompano Beach      PB
# 1            2         2            7300 Pines Blvd    Pembroke Pines      PP
# 2            3         3  3100 Ray Ferrero, Jr Blvd             Davie      DV
# 3            4         4          100 S Andrews Ave   Fort Lauderdale      FL
# 4            5         5         3403 Galt Ocean Dr   Fort Lauderdale      FL
# 5            6         6         5985 N Federal Hwy   Fort Lauderdale      FL
# 6            7         7    1100 Coconut Creek Blvd     Coconut Creek      CK
# 7            8         8          300 S Federal Hwy        Hallandale      HD
# 8            9         9    2050 Civic Center Place           Miramar      MM
# 9           10        10            4735 SW 18th St         West Park      WP
# 10          11        11            1301 S Ocean Dr         Hollywood      HW
# ...

# %%
# that was incorrect. must define branches_trimmed first

# %%
branches_trimmed=['ADDRESS', 'CITY', 'ZIPCODE', 'AGE', 'LAT', 'LON', 'LIBNAME', 'BUFF_DIST', 'geometry']

# %%
branches[branches_trimmed].head()
# Out:
#                      ADDRESS             CITY ZIPCODE   AGE        LAT  \
# 0         50 W Atlantic Blvd    Pompano Beach   33060  1952  26.232160
# 1            7300 Pines Blvd   Pembroke Pines   33023  2007  26.007629
# 2  3100 Ray Ferrero, Jr Blvd            Davie   33314  2001  26.079382
# 3          100 S Andrews Ave  Fort Lauderdale   33301  1984  26.120944
# 4         3403 Galt Ocean Dr  Fort Lauderdale   33308  1992  26.170162
#
#          LON                                            LIBNAME  BUFF_DIST  \
# 0 -80.110781          Pompano Beach Library and Cultural Center       0.25
# 1 -80.234838                         South Regional/Bcc Library       0.25
# 2 -80.242510  Alvin Sherman, Research And Info. Tech. Ctr At...       0.25
# 3 -80.142853                                       Main Library       0.25
# 4 -80.099514                     Galt Ocean Mile Reading Center       0.25
#
#                                             geometry
# ...

# %%
branches_trimmed=branches.copy()

# %%
branches_trimmed.head()
# Out:
#    OBJECTID_1  OBJECTID                    ADDRESS             CITY CITY_ID  \
# 0           1         1         50 W Atlantic Blvd    Pompano Beach      PB
# 1           2         2            7300 Pines Blvd   Pembroke Pines      PP
# 2           3         3  3100 Ray Ferrero, Jr Blvd            Davie      DV
# 3           4         4          100 S Andrews Ave  Fort Lauderdale      FL
# 4           5         5         3403 Galt Ocean Dr  Fort Lauderdale      FL
#
#   ZIPCODE     PHONE  SVCAREA                    TYPE TYPE3  ...  \
# 0   33060  357-7595        3  Branch/Cultural Center     B  ...
# 1   33023  201-8825        5                Regional     R  ...
# 2   33314  262-5477        5                     NSU   NSU  ...
# 3   33301  357-7444        5                    MAIN  MAIN  ...
# 4   33308  537-2877        1          Reading Center    RC  ...
#
#                                              LIBNAME  COMDIST  BUFF_DIST  \
# ...

# %%
# I'm not sure what I'm doing wrong in this part so I'm going to use the desired_columns method instead

# %%
# list of desired column names
desired_columns = ['ADDRESS', 'CITY', 'ZIPCODE', 'AGE', 'LAT', 'LON', 'LIBNAME', 'BUFF_DIST', 'geometry']

# %%
# subset based on desired columns
branches[desired_columns].sample(5)
# Out:
#                     ADDRESS              CITY ZIPCODE   AGE        LAT  \
# 52      2200 NE 38th Street  Lighthouse Point   33064         0.000000
# 23  501 North Fig Tree Lane        Plantation   33317        26.128298
# 33   8701 W Commercial Blvd           Tamarac   33351  2003  26.194311
# 20      751 SW 121st Avenue             Davie   33325        26.111880
# 5        5985 N Federal Hwy   Fort Lauderdale   33308  1988  26.202059
#
#           LON                                     LIBNAME  BUFF_DIST  \
# 52   0.000000    Doreen Gauthier Lighthouse Point Library       0.25
# 23 -80.227772         Helen B. Hoffman Plantation Library       0.25
# 33 -80.266802                              Tamarac Branch       0.25
# 20 -80.310007  Young at Art Museum/Broward County Library       0.25
# 5  -80.109941                       Imperial Point Branch       0.25
#
#                                              geometry
# 52  POLYGON ((-80.09387 26.28090, -80.09405 26.280...
# ...

# %%
branches.head()
# Out:
#    OBJECTID_1  OBJECTID                    ADDRESS             CITY CITY_ID  \
# 0           1         1         50 W Atlantic Blvd    Pompano Beach      PB
# 1           2         2            7300 Pines Blvd   Pembroke Pines      PP
# 2           3         3  3100 Ray Ferrero, Jr Blvd            Davie      DV
# 3           4         4          100 S Andrews Ave  Fort Lauderdale      FL
# 4           5         5         3403 Galt Ocean Dr  Fort Lauderdale      FL
#
#   ZIPCODE     PHONE  SVCAREA                    TYPE TYPE3  ...  \
# 0   33060  357-7595        3  Branch/Cultural Center     B  ...
# 1   33023  201-8825        5                Regional     R  ...
# 2   33314  262-5477        5                     NSU   NSU  ...
# 3   33301  357-7444        5                    MAIN  MAIN  ...
# 4   33308  537-2877        1          Reading Center    RC  ...
#
#                                              LIBNAME  COMDIST  BUFF_DIST  \
# ...

# %%
branches_trimmed=branches[desired_columns].copy()

# %%
branches_trimmed
# Out:
#                       ADDRESS              CITY ZIPCODE   AGE        LAT  \
# 0          50 W Atlantic Blvd     Pompano Beach   33060  1952  26.232160
# 1             7300 Pines Blvd    Pembroke Pines   33023  2007  26.007629
# 2   3100 Ray Ferrero, Jr Blvd             Davie   33314  2001  26.079382
# 3           100 S Andrews Ave   Fort Lauderdale   33301  1984  26.120944
# 4          3403 Galt Ocean Dr   Fort Lauderdale   33308  1992  26.170162
# 5          5985 N Federal Hwy   Fort Lauderdale   33308  1988  26.202059
# 6     1100 Coconut Creek Blvd     Coconut Creek   33066  1994  26.242025
# 7           300 S Federal Hwy        Hallandale   33009  1981  25.981205
# 8     2050 Civic Center Place           Miramar   33025  2008  25.988215
# 9             4735 SW 18th St         West Park   33023  1982  25.994785
# 10            1301 S Ocean Dr         Hollywood   33019  1994  26.004002
# 11        2600 Hollywood Blvd         Hollywood   33020  2006  26.010716
# ...

# %%
# to see a subset of the data, I can use the .loc command. This code gives me the libraries just in Fort Lauderdale.
branches_trimmed.loc[branches_trimmed['CITY']=='Fort Lauderdale']
# Out:
#                 ADDRESS             CITY ZIPCODE   AGE        LAT        LON  \
# 3     100 S Andrews Ave  Fort Lauderdale   33301  1984  26.120944 -80.142853
# 4    3403 Galt Ocean Dr  Fort Lauderdale   33308  1992  26.170162 -80.099514
# 5    5985 N Federal Hwy  Fort Lauderdale   33308  1988  26.202059 -80.109941
# 19    2710 W Davie Blvd  Fort Lauderdale   33312  1974  26.105074 -80.177990
# 21    201 SE 6th Street  Fort Lauderdale   33301        26.114871 -80.140858
# 24   2650 Sistrunk Blvd  Fort Lauderdale   33311  2002  26.128325 -80.177517
# 25  1300 E Sunrise Blvd  Fort Lauderdale   33304  1948  26.136775 -80.130221
# 27     2230 NW 21st Ave  Fort Lauderdale   33311  2008  26.156051 -80.169492
#
#                                               LIBNAME  BUFF_DIST  \
# 3                                        Main Library       0.25
# 4                      Galt Ocean Mile Reading Center       0.25
# 5                               Imperial Point Branch       0.25
# ...

# %%
# or I can use the .query command. This code gives me the libraries in Parkland.
branches_trimmed.query("CITY == 'Parkland'")
# Out:
#                   ADDRESS      CITY ZIPCODE AGE       LAT        LON  \
# 41  6620 University Drive  Parkland   33067      26.31124 -80.251421
# 49  6620 University Drive  Parkland   33067       0.00000   0.000000
# 53  6600 University Drive  Parkland   33067       0.00000   0.000000
#
#              LIBNAME  BUFF_DIST  \
# 41  Parkland Library       0.25
# 49  Parkland Library       0.25
# 53  City of Parkland       0.25
#
#                                              geometry
# 41  POLYGON ((-80.25142 26.31487, -80.25160 26.314...
# 49  POLYGON ((-80.25114 26.31483, -80.25132 26.314...
# 53  POLYGON ((-80.25239 26.31523, -80.25257 26.315...

# %%
branches_trimmed.plot()
# Out:
# <AxesSubplot:>

# %%
branches.geometry
# Out:
# 0     POLYGON ((-80.12393 26.23433, -80.12411 26.234...
# 1     POLYGON ((-80.23484 26.01126, -80.23502 26.011...
# 2     POLYGON ((-80.24251 26.08301, -80.24269 26.083...
# 3     POLYGON ((-80.14285 26.12458, -80.14303 26.124...
# 4     POLYGON ((-80.09951 26.17379, -80.09969 26.173...
# 5     POLYGON ((-80.10994 26.20569, -80.11012 26.205...
# 6     POLYGON ((-80.17170 26.24566, -80.17188 26.245...
# 7     POLYGON ((-80.14283 25.98484, -80.14300 25.984...
# 8     POLYGON ((-80.30080 25.99185, -80.30098 25.991...
# 9     POLYGON ((-80.19089 25.99862, -80.19106 25.998...
# 10    POLYGON ((-80.11755 26.00763, -80.11773 26.007...
# 11    POLYGON ((-80.15858 26.01435, -80.15876 26.014...
# 12    POLYGON ((-80.32308 26.01779, -80.32325 26.017...
# 13    POLYGON ((-80.37315 26.03457, -80.37333 26.034...
# 14    POLYGON ((-80.21471 26.04110, -80.21489 26.041...
# 15    POLYGON ((-80.18595 26.05195, -80.18612 26.051...
# 16    POLYGON ((-80.14470 26.05558, -80.14488 26.055...
# ...

# %%
# this code will give me a plot with colored markers
branches_trimmed.plot(
                figsize = (12,20), 
                column = 'CITY',
                legend = True, 
                legend_kwds = {
                    'loc' : 'upper right', 
                    'bbox_to_anchor':(1.2,1)
        }
)
# Out:
# <AxesSubplot:>

# %%
import folium

# %%
m=folium.map
m
# Out:
# <module 'folium.map' from '/opt/conda/lib/python3.9/site-packages/folium/map.py'>

# %%
latitude = branches_trimmed.LAT.mean()
latitude
# Out:
# 20.440136692

# %%
longitude = branches_trimmed.LON.mean()
longitude
# Out:
# -65.61348467563637

# %%
# I am not sure why but these coordinates center the map off the coast of PR, not in Broward County or even Florida....
m = folium.Map(location=[20.440136692,-65.61348467563637])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
# now I'm going to add markers for each library in the county
# first, loop through a data frame
for index, row in branches_trimmed.iterrows():
    print(row.LIBNAME, row.LAT, row.LON)
# Out:
# Pompano Beach Library and Cultural Center 26.23215993 -80.11078065
# South Regional/Bcc Library 26.00762941 -80.23483754
# Alvin Sherman, Research And Info. Tech. Ctr At Nsu 26.0793822 -80.24251008
# Main Library 26.12094419 -80.1428533
# Galt Ocean Mile Reading Center 26.17016222 -80.0995137
# Imperial Point Branch 26.20205882 -80.10994081
# North Regional/Bcc Library 26.24202508 -80.17169738
# Hallandale Beach Branch 25.9812049 -80.14282535
# Miramar Branch Library & Education Center 25.98821525 -80.30080153
# Carver Ranches Branch 25.99478543 -80.19070449
# Hollywood Beach Bernice P. Oster Reading 26.00400232 -80.11755459
# Hollywood Branch 26.01071629 -80.15858428
# Pembroke Pines Branch/Walter C. Young Resource Ctr 26.0141577 -80.32307564
# Southwest Regional Library 26.03093988 -80.37315106
# Dorothy Scott Osceola Memorial Library Hollywood Reservation 26.03747005 -80.21471412
# Stirling Road Library 26.04832298 -80.18594587
# ...

# %%
# add the zipcodes
for index, row in branches_trimmed.iterrows():
    # add folium marker code
    folium.Marker([row.LAT, row.LON], popup=row.LIBNAME, tooltip=row.LIBNAME).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
# Now I'm going to color code the markers. In the end each city should be a differerent color.
branches_trimmed['COLOR']=''

# %%
branches_trimmed.head()
# Out:
#                      ADDRESS             CITY ZIPCODE   AGE        LAT  \
# 0         50 W Atlantic Blvd    Pompano Beach   33060  1952  26.232160
# 1            7300 Pines Blvd   Pembroke Pines   33023  2007  26.007629
# 2  3100 Ray Ferrero, Jr Blvd            Davie   33314  2001  26.079382
# 3          100 S Andrews Ave  Fort Lauderdale   33301  1984  26.120944
# 4         3403 Galt Ocean Dr  Fort Lauderdale   33308  1992  26.170162
#
#          LON                                            LIBNAME  BUFF_DIST  \
# 0 -80.110781          Pompano Beach Library and Cultural Center       0.25
# 1 -80.234838                         South Regional/Bcc Library       0.25
# 2 -80.242510  Alvin Sherman, Research And Info. Tech. Ctr At...       0.25
# 3 -80.142853                                       Main Library       0.25
# 4 -80.099514                     Galt Ocean Mile Reading Center       0.25
#
#                                             geometry
# ...

# %%
# Here I'll search for different values in the CITY column
branches_trimmed.CITY.unique()
# Out:
# array(['Pompano Beach', 'Pembroke Pines', 'Davie', 'Fort Lauderdale',
#        'Coconut Creek', 'Hallandale', 'Miramar', 'West Park', 'Hollywood',
#        'Dania Beach', 'Weston', 'Plantation', 'Lauderhill',
#        'Wilton Manors', 'Lauderdale Lakes', 'Sunrise', 'Oakland Park',
#        'Tamarac', 'North Lauderdale', 'Margate', 'Coral Springs',
#        'Lighthouse Point', 'Parkland', 'Deerfield Beach',
#        'Hallandale Beach'], dtype=object)

# %%
# Display rows that match query
branches_trimmed.loc[branches_trimmed['CITY'] == 'Pompano Beach']
# Out:
#                ADDRESS           CITY ZIPCODE   AGE        LAT        LON  \
# 0   50 W Atlantic Blvd  Pompano Beach   33060  1952  26.232160 -80.110781
# 35  3250 NE 2nd Street  Pompano Beach   33062  1986  26.235684 -80.089460
# 36      2800 NW 9th Ct  Pompano Beach   33069  1977  26.240165 -80.160702
# 38     1580 NW 3rd Ave  Pompano Beach   33060  2005  26.248779 -80.126626
#
#                                       LIBNAME  BUFF_DIST  \
# 0   Pompano Beach Library and Cultural Center       0.25
# 35                               Beach Branch       0.25
# 36    Jan Moran Collier City Learning Library       0.25
# 38                           Northwest Branch       0.25
#
#                                              geometry COLOR
# 0   POLYGON ((-80.12393 26.23433, -80.12411 26.234...
# 35  POLYGON ((-80.09163 26.23894, -80.09181 26.238...
# 36  POLYGON ((-80.16070 26.24380, -80.16088 26.243...
# 38  POLYGON ((-80.12663 26.25241, -80.12681 26.252...

# %%
branches_trimmed.loc[branches_trimmed['CITY'] == 'Pompano Beach', 'COLOR'] = 'orange'

# %%
branches_trimmed.loc[branches_trimmed['CITY'] == 'Pompano Beach']
# Out:
#                ADDRESS           CITY ZIPCODE   AGE        LAT        LON  \
# 0   50 W Atlantic Blvd  Pompano Beach   33060  1952  26.232160 -80.110781
# 35  3250 NE 2nd Street  Pompano Beach   33062  1986  26.235684 -80.089460
# 36      2800 NW 9th Ct  Pompano Beach   33069  1977  26.240165 -80.160702
# 38     1580 NW 3rd Ave  Pompano Beach   33060  2005  26.248779 -80.126626
#
#                                       LIBNAME  BUFF_DIST  \
# 0   Pompano Beach Library and Cultural Center       0.25
# 35                               Beach Branch       0.25
# 36    Jan Moran Collier City Learning Library       0.25
# 38                           Northwest Branch       0.25
#
#                                              geometry   COLOR
# 0   POLYGON ((-80.12393 26.23433, -80.12411 26.234...  orange
# 35  POLYGON ((-80.09163 26.23894, -80.09181 26.238...  orange
# 36  POLYGON ((-80.16070 26.24380, -80.16088 26.243...  orange
# ...

# %%
branches_trimmed.loc[branches_trimmed['CITY'] == 'Fort Lauderdale', 'COLOR'] = 'red'

# %%
branches_trimmed.loc[branches_trimmed['CITY'] == 'Fort Lauderdale']
# Out:
#                 ADDRESS             CITY ZIPCODE   AGE        LAT        LON  \
# 3     100 S Andrews Ave  Fort Lauderdale   33301  1984  26.120944 -80.142853
# 4    3403 Galt Ocean Dr  Fort Lauderdale   33308  1992  26.170162 -80.099514
# 5    5985 N Federal Hwy  Fort Lauderdale   33308  1988  26.202059 -80.109941
# 19    2710 W Davie Blvd  Fort Lauderdale   33312  1974  26.105074 -80.177990
# 21    201 SE 6th Street  Fort Lauderdale   33301        26.114871 -80.140858
# 24   2650 Sistrunk Blvd  Fort Lauderdale   33311  2002  26.128325 -80.177517
# 25  1300 E Sunrise Blvd  Fort Lauderdale   33304  1948  26.136775 -80.130221
# 27     2230 NW 21st Ave  Fort Lauderdale   33311  2008  26.156051 -80.169492
#
#                                               LIBNAME  BUFF_DIST  \
# 3                                        Main Library       0.25
# 4                      Galt Ocean Mile Reading Center       0.25
# 5                               Imperial Point Branch       0.25
# ...

# %%
branches_trimmed.loc[branches_trimmed['CITY'] == 'Hollywood', 'COLOR'] = 'green'

# %%
branches_trimmed.loc[branches_trimmed['CITY'] == 'Hollywood']
# Out:
#                 ADDRESS       CITY ZIPCODE   AGE        LAT        LON  \
# 10      1301 S Ocean Dr  Hollywood   33019  1994  26.004002 -80.117555
# 11  2600 Hollywood Blvd  Hollywood   33020  2006  26.010716 -80.158584
# 14  3100 NW 63rd Avenue  Hollywood   33024        26.037470 -80.214714
# 15     3151 Stirling Rd  Hollywood   33312  2003  26.048323 -80.185946
# 54   6300 Stirling Road  Hollywood   33024         0.000000   0.000000
#
#                                               LIBNAME  BUFF_DIST  \
# 10           Hollywood Beach Bernice P. Oster Reading       0.25
# 11                                   Hollywood Branch       0.25
# 14  Dorothy Scott Osceola Memorial Library Hollywo...       0.25
# 15                              Stirling Road Library       0.25
# 54                          Seminole Tribe of Florida       0.25
#
#                                              geometry  COLOR
# 10  POLYGON ((-80.11755 26.00763, -80.11773 26.007...  green
# ...

# %%
branches_trimmed.loc[branches_trimmed['CITY'] == 'Plantation', 'COLOR'] = 'purple'

# %%
branches_trimmed.loc[branches_trimmed['CITY'] == 'Plantation']
# Out:
#                     ADDRESS        CITY ZIPCODE   AGE        LAT        LON  \
# 22      8601 W Broward Blvd  Plantation   33324  2007  26.121528 -80.261702
# 23  501 North Fig Tree Lane  Plantation   33317        26.128298 -80.227772
# 47      501 N Fig Tree Lane  Plantation   33317         0.000000   0.000000
# 51       400 NW 73rd Avenue  Plantation   33317         0.000000   0.000000
#
#                                 LIBNAME  BUFF_DIST  \
# 22                West Regional Library       0.25
# 23  Helen B. Hoffman Plantation Library       0.25
# 47  Helen B. Hoffman Plantation Library       0.25
# 51                   City of Plantation       0.25
#
#                                              geometry   COLOR
# 22  POLYGON ((-80.26170 26.12516, -80.26188 26.125...  purple
# 23  POLYGON ((-80.22777 26.13193, -80.22795 26.131...  purple
# 47  POLYGON ((-80.22777 26.13193, -80.22795 26.131...  purple
# 51  POLYGON ((-80.24371 26.13090, -80.24389 26.130...  purple

# %%
branches_trimmed.loc[branches_trimmed['CITY'] == 'Pembroke Pines', 'COLOR'] = 'tan'

# %%
branches_trimmed.loc[branches_trimmed['CITY'] == 'Pembroke Pines']
# Out:
#               ADDRESS            CITY ZIPCODE   AGE        LAT        LON  \
# 1     7300 Pines Blvd  Pembroke Pines   33023  2007  26.007629 -80.234838
# 12   955 NW 129th Ave  Pembroke Pines   33028  1999  26.014158 -80.323076
# 13  16835 Sheridan St  Pembroke Pines   33331  2000  26.030940 -80.373151
#
#                                               LIBNAME  BUFF_DIST  \
# 1                          South Regional/Bcc Library       0.25
# 12  Pembroke Pines Branch/Walter C. Young Resource...       0.25
# 13                         Southwest Regional Library       0.25
#
#                                              geometry COLOR
# 1   POLYGON ((-80.23484 26.01126, -80.23502 26.011...   tan
# 12  POLYGON ((-80.32308 26.01779, -80.32325 26.017...   tan
# 13  POLYGON ((-80.37315 26.03457, -80.37333 26.034...   tan

# %%
branches_trimmed.loc[branches_trimmed['CITY'] == 'Davie', 'COLOR'] = 'cyan'

# %%
branches_trimmed.loc[branches_trimmed['CITY'] == 'Davie']
# Out:
#                       ADDRESS   CITY ZIPCODE   AGE        LAT        LON  \
# 2   3100 Ray Ferrero, Jr Blvd  Davie   33314  2001  26.079382 -80.242510
# 17           4600 SW 82nd Ave  Davie   33328  1982  26.063991 -80.255740
# 20        751 SW 121st Avenue  Davie   33325        26.111880 -80.310007
#
#                                               LIBNAME  BUFF_DIST  \
# 2   Alvin Sherman, Research And Info. Tech. Ctr At...       0.25
# 17                           Davie/Cooper City Branch       0.25
# 20         Young at Art Museum/Broward County Library       0.25
#
#                                              geometry COLOR
# 2   POLYGON ((-80.24251 26.08301, -80.24269 26.083...  cyan
# 17  POLYGON ((-80.25574 26.06762, -80.25592 26.067...  cyan
# 20  POLYGON ((-80.31001 26.11551, -80.31019 26.115...  cyan

# %%
branches_trimmed.loc[branches_trimmed['CITY'] == 'Coconut Creek', 'COLOR'] = 'brown'

# %%
branches_trimmed.loc[branches_trimmed['CITY'] == 'Coconut Creek']
# Out:
#                    ADDRESS           CITY ZIPCODE   AGE        LAT        LON  \
# 6  1100 Coconut Creek Blvd  Coconut Creek   33066  1994  26.242025 -80.171697
#
#                       LIBNAME  BUFF_DIST  \
# 6  North Regional/Bcc Library       0.25
#
#                                             geometry  COLOR
# 6  POLYGON ((-80.17170 26.24566, -80.17188 26.245...  brown

# %%
branches_trimmed.loc[branches_trimmed['CITY'] == 'Hallandale', 'COLOR'] = 'yellow'

# %%
branches_trimmed.loc[branches_trimmed['CITY'] == 'Hallandale']
# Out:
#              ADDRESS        CITY ZIPCODE   AGE        LAT        LON  \
# 7  300 S Federal Hwy  Hallandale   33009  1981  25.981205 -80.142825
#
#                    LIBNAME  BUFF_DIST  \
# 7  Hallandale Beach Branch       0.25
#
#                                             geometry   COLOR
# 7  POLYGON ((-80.14283 25.98484, -80.14300 25.984...  yellow

# %%
branches_trimmed.loc[branches_trimmed['CITY'] == 'Miramar', 'COLOR'] = 'gray'

# %%
branches_trimmed.loc[branches_trimmed['CITY'] == 'Miramar']
# Out:
#                    ADDRESS     CITY ZIPCODE   AGE        LAT        LON  \
# 8  2050 Civic Center Place  Miramar   33025  2008  25.988215 -80.300802
#
#                                      LIBNAME  BUFF_DIST  \
# 8  Miramar Branch Library & Education Center       0.25
#
#                                             geometry COLOR
# 8  POLYGON ((-80.30080 25.99185, -80.30098 25.991...  gray

# %%
branches_trimmed.loc[branches_trimmed['CITY'] == 'West Park', 'COLOR'] = 'navy'

# %%
branches_trimmed.loc[branches_trimmed['CITY'] == 'West Park']
# Out:
#            ADDRESS       CITY ZIPCODE   AGE        LAT        LON  \
# 9  4735 SW 18th St  West Park   33023  1982  25.994785 -80.190704
#
#                  LIBNAME  BUFF_DIST  \
# 9  Carver Ranches Branch       0.25
#
#                                             geometry COLOR
# 9  POLYGON ((-80.19089 25.99862, -80.19106 25.998...  navy

# %%
branches_trimmed.loc[branches_trimmed['CITY'] == 'Dania Beach', 'COLOR'] = 'lightblue'

# %%
branches_trimmed.loc[branches_trimmed['CITY'] == 'Dania Beach']
# Out:
#                ADDRESS         CITY ZIPCODE   AGE        LAT        LON  \
# 16  1 Park Avenue East  Dania Beach   33004  1961  26.052892 -80.139372
#
#                            LIBNAME  BUFF_DIST  \
# 16  Dania Beach Paul Demaio Branch       0.25
#
#                                              geometry      COLOR
# 16  POLYGON ((-80.14470 26.05558, -80.14488 26.055...  lightblue
