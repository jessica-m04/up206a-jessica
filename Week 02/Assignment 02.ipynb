# %%
import geopandas as gpd

# %%
housing=gpd.read_file("DATA/LAHD_Affordable_Housing_Projects_List__2003_to_Present_.csv")

# %%
housing.head()
# Out:
#           APN PROJECT NUMBER                                NAME  \
# 0  5131020009      05-117217  LEXINGTON APARTMENTS A/B (SITE 11)
# 1  6071001013      06-117222       WINDWARD APTS (A/B) (SITE 14)
# 2  5544025033          60057                             BRICKER
# 3  5124011008      07-117233                 HDR I & II (SITE 4)
# 4  5502020005          80050              ALEXANDRIA HOUSE APTS.
#
#   DEVELOPMENT STAGE    CONSTRUCTION TYPE  \
# 0        In-Service                REHAB
# 1        In-Service                REHAB
# 2        In-Service  ACQUISITION + REHAB
# 3        In-Service                REHAB
# 4        In-Service                REHAB
#
#                                        SITE ADDRESS SITE  COUNCIL DISTRICT  \
# 0             1145 E 24TH ST  Los Angeles, CA 90011                      9
# 1         636 E 108TH ST 1-4  Los Angeles, CA 90059                      8
# 2         1671 N WESTERN AVE  Los Angeles, CA 90028                     13
# ...

# %%
housing.shape
# Out:
# (518, 31)

# %%
housing.info
# Out:
# <bound method DataFrame.info of             APN PROJECT NUMBER                                NAME  \
# 0    5131020009      05-117217  LEXINGTON APARTMENTS A/B (SITE 11)
# 1    6071001013      06-117222       WINDWARD APTS (A/B) (SITE 14)
# 2    5544025033          60057                             BRICKER
# 3    5124011008      07-117233                 HDR I & II (SITE 4)
# 4    5502020005          80050              ALEXANDRIA HOUSE APTS.
# ..          ...            ...                                 ...
# 513  5180001900      19-125934                          LA VERANDA
# 514  5149010949      18-124964         GRAND AVENUE PARCEL Q APTS.
# 515  5114014004      14-121652             FLORENCE MILLS (SITE 4)
# 516  5183005010      09-117211             LAS MARGARITAS (SITE 2)
# 517  5153006024          50035                         UNION POINT
#
#     DEVELOPMENT STAGE                CONSTRUCTION TYPE  \
# 0          In-Service                            REHAB
# ...

# %%
for col in housing.columns:
    print(col)
# Out:
# APN
# PROJECT NUMBER
# NAME
# DEVELOPMENT STAGE
# CONSTRUCTION TYPE
# SITE ADDRESS
# SITE  COUNCIL DISTRICT
# SITE #
# SITE COMMUNITY
# SITE UNITS
# PROJECT TOTAL UNITS
# HOUSING TYPE
# SUPPORTIVE HOUSING
# DATE FUNDED
# LAHD FUNDED
# LEVERAGE
# TAX EXEMPT CONDUIT BOND
# TDC
# IN-SERVICE DATE
# DEVELOPER
# MANAGEMENT COMPANY
# CONTACT PHONE
# PHOTO
# JOBS
# PROJECT SUMMARY URL
# CONTRACT NUMBERS
# DATE STAMP
# SITE LONGITUDE
# SITE LATITUDE
# GPS_COORDS ON MAP
# geometry

# %%
len(col)
# Out:
# 8
